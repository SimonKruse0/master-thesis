# %%
from collect_bayesopt_results import get_best_solutions_for_all_solvers

# %%
df = get_best_solutions_for_all_solvers()

# %%
df = df.sort_index(level=0)

# %%
df.index.get_level_values(0).unique()
# Out:
# Index(['BO_BOHAMIANN', 'BO_BOHAMIANN-001', 'BO_Gaussian_Process_-_sklearn',
#        'BO_Gaussian_Process_-_sklearn-001',
#        'BO_Gaussian_Process_-_sklearn-002',
#        'BO_Gaussian_Process_-_sklearn-003',
#        'BO_Naive_Gaussian_Mixture_Regression',
#        'BO_Naive_Gaussian_Mixture_Regression-001',
#        'BO_empirical_mean_and_std_regression',
#        'BO_empirical_mean_and_std_regression-001',
#        'BO_numpyro_neural_network200-200',
#        'BO_numpyro_neural_network200-200-001',
#        'BO_numpyro_neural_network200-200-002'],
#       dtype='object', name='first')

# %%
df.loc["BO_Gaussian_Process_-_sklearn":"BO_Gaussian_Process_-_sklearn-003"].loc[:,"DIM5","f"].mean()
# Out:
# f1     5.863391e+00
# f2     1.115986e+04
# f3     5.917711e+01
# f4     9.505880e+01
# f5     2.884203e+00
# f6     4.840695e+01
# f7     7.646855e+00
# f8     1.831470e+02
# f9     1.541418e+02
# f10    1.469134e+04
# f11    1.108149e+02
# f12    1.671682e+06
# f13    2.057026e+02
# f14    1.407909e-01
# f15    6.708088e+01
# f16    1.082488e+01
# f17    4.500886e+00
# f18    7.184919e+00
# f19    4.261516e+00
# f20    2.573775e+00
# f21    6.275375e+00
# f22    1.772904e+01
# f23    3.158355e+00
# f24    5.599409e+01
# dtype: float64

# %%
df.loc[:,"DIM2","f_evals"]
# Out:
#                                           f1   f2   f3   f4   f5   f6   f7  \
# first
# BO_BOHAMIANN                              39   27   11  NaN  NaN  NaN  NaN
# BO_BOHAMIANN-001                          26   27   11  NaN  NaN  NaN  NaN
# BO_Gaussian_Process_-_sklearn              9   39   14   35    6   32   12
# BO_Gaussian_Process_-_sklearn-001          5   39   18   13   28   32   12
# BO_Gaussian_Process_-_sklearn-002          9   26   21   22   28   32   12
# BO_Gaussian_Process_-_sklearn-003          9   22   31   32   28   32   12
# BO_Naive_Gaussian_Mixture_Regression      11   17   18   12   26   31   35
# BO_Naive_Gaussian_Mixture_Regression-001   7   39   12    5   16    9   16
# BO_empirical_mean_and_std_regression      33   17   10   27   15   21   28
# BO_empirical_mean_and_std_regression-001  16    3    7   34   30   20   21
# BO_numpyro_neural_network200-200           1  NaN  NaN  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001      19   39   36   39   28  NaN  NaN
# BO_numpyro_neural_network200-200-002      19   39   36   39   28    6  NaN
#
#                                            f8   f9  f10  ...  f15  f16  f17  \
# first                                                    ...
# BO_BOHAMIANN                              NaN  NaN  NaN  ...  NaN  NaN  NaN
# BO_BOHAMIANN-001                          NaN  NaN  NaN  ...  NaN  NaN  NaN
# BO_Gaussian_Process_-_sklearn              28   25   34  ...   15   10   29
# BO_Gaussian_Process_-_sklearn-001          18   25   29  ...   39   10    7
# BO_Gaussian_Process_-_sklearn-002          18   25   35  ...   39   10   25
# BO_Gaussian_Process_-_sklearn-003          11   25   35  ...   19   10   13
# BO_Naive_Gaussian_Mixture_Regression        2    7   18  ...   34   33    5
# BO_Naive_Gaussian_Mixture_Regression-001    2   24   36  ...    7    8   14
# BO_empirical_mean_and_std_regression       31    1    6  ...   23   31   27
# BO_empirical_mean_and_std_regression-001   17   15   22  ...   26    7   16
# BO_numpyro_neural_network200-200          NaN  NaN  NaN  ...  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001      NaN  NaN  NaN  ...  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-002      NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                           f18  f19  f20  f21  f22  f23  f24
# first
# BO_BOHAMIANN                              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# BO_BOHAMIANN-001                          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# BO_Gaussian_Process_-_sklearn              14   39   35    8   17   23   31
# BO_Gaussian_Process_-_sklearn-001           6   17   20   36   10   32   16
# BO_Gaussian_Process_-_sklearn-002           5   17   31   19   13    9    5
# BO_Gaussian_Process_-_sklearn-003          15   35   30   27   11    5   25
# BO_Naive_Gaussian_Mixture_Regression       35    5   28    9    5    4   38
# BO_Naive_Gaussian_Mixture_Regression-001   13    5    3   34    3    6   15
# BO_empirical_mean_and_std_regression       15   11   20    1   32   12   10
# BO_empirical_mean_and_std_regression-001   12    8   14   29   12   15    3
# BO_numpyro_neural_network200-200          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-002      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13 rows x 24 columns]

# %%
df
# Out:
#                                                            f1          f2  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f             NaN         NaN
#                                             f_evals       NaN         NaN
#                                      DIM2   f        0.074467  552.830941
#                                             f_evals        39          27
#                                      DIM20  f             NaN         NaN
# ...                                                       ...         ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals       NaN         NaN
#                                      DIM40  f             NaN         NaN
#                                             f_evals       NaN         NaN
#                                      DIM5   f             NaN         NaN
#                                             f_evals       NaN         NaN
#
#                                                             f3   f4   f5   f6  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f              NaN  NaN  NaN  NaN
#                                             f_evals        NaN  NaN  NaN  NaN
#                                      DIM2   f        17.356998  NaN  NaN  NaN
#                                             f_evals         11  NaN  NaN  NaN
#                                      DIM20  f              NaN  NaN  NaN  NaN
# ...                                                        ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals        NaN  NaN  NaN  NaN
#                                      DIM40  f              NaN  NaN  NaN  NaN
#                                             f_evals        NaN  NaN  NaN  NaN
#                                      DIM5   f              NaN  NaN  NaN  NaN
#                                             f_evals        NaN  NaN  NaN  NaN
#
#                                                       f7   f8   f9  f10  ...  \
# first                                second third                        ...
# BO_BOHAMIANN                         DIM10  f        NaN  NaN  NaN  NaN  ...
#                                             f_evals  NaN  NaN  NaN  NaN  ...
#                                      DIM2   f        NaN  NaN  NaN  NaN  ...
#                                             f_evals  NaN  NaN  NaN  NaN  ...
#                                      DIM20  f        NaN  NaN  NaN  NaN  ...
# ...                                                  ...  ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  NaN  NaN  NaN  NaN  ...
#                                      DIM40  f        NaN  NaN  NaN  NaN  ...
#                                             f_evals  NaN  NaN  NaN  NaN  ...
#                                      DIM5   f        NaN  NaN  NaN  NaN  ...
#                                             f_evals  NaN  NaN  NaN  NaN  ...
#
#                                                      f15  f16  f17  f18  f19  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#
#                                                      f20  f21  f22  f23  f24
# first                                second third
# BO_BOHAMIANN                         DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#
# [156 rows x 24 columns]

# %%
import latextable
from texttable import Texttable

# %%
table_1 = Texttable()
table_1.set_cols_align(["l", "r", "c"])
table_1.set_cols_valign(["t", "m", "b"])
#table.set_cols_align(["c"] * 4)
table_1.set_deco(Texttable.HEADER | Texttable.VLINES)
table_1.add_rows([["Name", "Age", "Nickname"],
                 ["Mr\nXavier\nHuon", 32, "Xav'"],
                 ["Mr\nBaptiste\nClement", 1, "Baby"],
                 ["Mme\nLouise\nBourgeau", 28, "Lou\n \nLoue"]])

# %%
texdoc = latextable.draw_latex(table_1, caption="An example table.", label="table:example_table")
path = "/home/simon/Documents/MasterThesis/master-thesis/thesis/Tables"
with open(f'{path}/test.tex', 'w') as fout:
    for i in range(len(texdoc)):
        fout.write(texdoc[i])
