# %%
from collect_bayesopt_results import get_best_solutions_for_all_solvers

# %%
get_best_solutions_for_all_solvers()
# Out:
#                                                                  f1  \
# first                                    second third
# BO_GP                                    DIM2   f          0.243744
#                                                 f_evals           7
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_empirical_mean_and_std_regression     DIM2   f          0.336848
#                                                 f_evals          12
#                                          DIM3   f          0.348226
#                                                 f_evals          64
#                                          DIM5   f          5.579091
#                                                 f_evals         118
#                                          DIM10  f         18.715384
#                                                 f_evals           6
#                                          DIM20  f        100.598554
#                                                 f_evals           6
#                                          DIM40  f        251.257799
#                                                 f_evals         542
# BO_naiveBayes                            DIM2   f          1.612658
#                                                 f_evals          51
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_naiveBayes-001                        DIM2   f          0.336848
#                                                 f_evals          12
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f               NaN
#                                                 f_evals         NaN
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
#
#                                                                   f2  \
# first                                    second third
# BO_GP                                    DIM2   f        4143.549888
#                                                 f_evals           16
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f         885.257743
#                                                 f_evals           11
#                                          DIM3   f        16385.06179
#                                                 f_evals            4
#                                          DIM5   f        55519.71046
#                                                 f_evals           79
#                                          DIM10  f        315987.4514
#                                                 f_evals          175
#                                          DIM20  f        846119.5583
#                                                 f_evals          561
#                                          DIM40  f        5762707.842
#                                                 f_evals          565
# BO_naiveBayes                            DIM2   f          90.120012
#                                                 f_evals           29
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f         885.257743
#                                                 f_evals           11
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                   f3  \
# first                                    second third
# BO_GP                                    DIM2   f          32.880076
#                                                 f_evals           16
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f          22.468945
#                                                 f_evals           30
#                                          DIM3   f          36.595042
#                                                 f_evals           15
#                                          DIM5   f          66.102792
#                                                 f_evals           42
#                                          DIM10  f         138.942634
#                                                 f_evals          123
#                                          DIM20  f         679.456686
#                                                 f_evals          206
#                                          DIM40  f        1542.736323
#                                                 f_evals          958
# BO_naiveBayes                            DIM2   f           7.494504
#                                                 f_evals           55
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f          22.468945
#                                                 f_evals           30
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                   f4  \
# first                                    second third
# BO_GP                                    DIM2   f          18.210004
#                                                 f_evals           14
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f          14.145398
#                                                 f_evals            2
#                                          DIM3   f            41.7961
#                                                 f_evals           45
#                                          DIM5   f          96.142777
#                                                 f_evals          117
#                                          DIM10  f         208.017188
#                                                 f_evals          243
#                                          DIM20  f         680.949184
#                                                 f_evals          164
#                                          DIM40  f        2509.394285
#                                                 f_evals          878
# BO_naiveBayes                            DIM2   f          14.145398
#                                                 f_evals            2
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f          14.145398
#                                                 f_evals            2
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                  f5  \
# first                                    second third
# BO_GP                                    DIM2   f          2.652351
#                                                 f_evals           5
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_empirical_mean_and_std_regression     DIM2   f          8.966524
#                                                 f_evals          22
#                                          DIM3   f          7.469069
#                                                 f_evals          21
#                                          DIM5   f         37.279429
#                                                 f_evals         137
#                                          DIM10  f         62.346692
#                                                 f_evals         255
#                                          DIM20  f        227.206586
#                                                 f_evals         351
#                                          DIM40  f        461.157274
#                                                 f_evals         618
# BO_naiveBayes                            DIM2   f             5.775
#                                                 f_evals          39
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_naiveBayes-001                        DIM2   f          8.966524
#                                                 f_evals          22
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f               NaN
#                                                 f_evals         NaN
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
#
#                                                                   f6  \
# first                                    second third
# BO_GP                                    DIM2   f          16.130155
#                                                 f_evals           19
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f          10.463246
#                                                 f_evals            8
#                                          DIM3   f           8.006003
#                                                 f_evals           70
#                                          DIM5   f          82.933124
#                                                 f_evals           55
#                                          DIM10  f         220.165452
#                                                 f_evals          258
#                                          DIM20  f        375808.8096
#                                                 f_evals          599
#                                          DIM40  f        830369.9992
#                                                 f_evals         1108
# BO_naiveBayes                            DIM2   f           4.167739
#                                                 f_evals           12
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f          10.463246
#                                                 f_evals            8
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                   f7  \
# first                                    second third
# BO_GP                                    DIM2   f           0.600916
#                                                 f_evals           14
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f           0.484314
#                                                 f_evals            1
#                                          DIM3   f            6.82349
#                                                 f_evals           26
#                                          DIM5   f          18.930063
#                                                 f_evals           67
#                                          DIM10  f         117.045059
#                                                 f_evals           88
#                                          DIM20  f         618.720089
#                                                 f_evals           73
#                                          DIM40  f        1101.291531
#                                                 f_evals          264
# BO_naiveBayes                            DIM2   f           0.484314
#                                                 f_evals            1
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f           0.484314
#                                                 f_evals            1
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                   f8  \
# first                                    second third
# BO_GP                                    DIM2   f          55.585019
#                                                 f_evals           11
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f           0.263093
#                                                 f_evals           35
#                                          DIM3   f          96.975933
#                                                 f_evals           32
#                                          DIM5   f         929.077348
#                                                 f_evals           28
#                                          DIM10  f        14338.29129
#                                                 f_evals          185
#                                          DIM20  f        86228.81431
#                                                 f_evals          314
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes                            DIM2   f          27.358783
#                                                 f_evals           29
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f           0.263093
#                                                 f_evals           35
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                   f9  \
# first                                    second third
# BO_GP                                    DIM2   f           19.68714
#                                                 f_evals           10
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f            2.29816
#                                                 f_evals            8
#                                          DIM3   f           49.94618
#                                                 f_evals           47
#                                          DIM5   f        1679.120278
#                                                 f_evals           18
#                                          DIM10  f         6403.55428
#                                                 f_evals           68
#                                          DIM20  f        51073.17485
#                                                 f_evals          141
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes                            DIM2   f           16.61721
#                                                 f_evals           29
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f            2.29816
#                                                 f_evals            8
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                  f10  ...  \
# first                                    second third                 ...
# BO_GP                                    DIM2   f         369.164006  ...
#                                                 f_evals            6  ...
#                                          DIM3   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM5   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM10  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM20  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM40  f                NaN  ...
#                                                 f_evals          NaN  ...
# BO_empirical_mean_and_std_regression     DIM2   f        5975.587137  ...
#                                                 f_evals            4  ...
#                                          DIM3   f        16873.76083  ...
#                                                 f_evals           45  ...
#                                          DIM5   f         53058.8465  ...
#                                                 f_evals           75  ...
#                                          DIM10  f        673093.3054  ...
#                                                 f_evals          252  ...
#                                          DIM20  f        1401343.559  ...
#                                                 f_evals          427  ...
#                                          DIM40  f                NaN  ...
#                                                 f_evals          NaN  ...
# BO_naiveBayes                            DIM2   f        5260.665126  ...
#                                                 f_evals           57  ...
#                                          DIM3   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM5   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM10  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM20  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM40  f                NaN  ...
#                                                 f_evals          NaN  ...
# BO_naiveBayes-001                        DIM2   f        5975.587137  ...
#                                                 f_evals            4  ...
#                                          DIM3   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM5   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM10  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM20  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM40  f                NaN  ...
#                                                 f_evals          NaN  ...
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM3   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM5   f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM10  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM20  f                NaN  ...
#                                                 f_evals          NaN  ...
#                                          DIM40  f                NaN  ...
#                                                 f_evals          NaN  ...
#
#                                                                 f15  \
# first                                    second third
# BO_GP                                    DIM2   f          1.584741
#                                                 f_evals          18
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_empirical_mean_and_std_regression     DIM2   f          4.007262
#                                                 f_evals          18
#                                          DIM3   f         26.790357
#                                                 f_evals          84
#                                          DIM5   f         41.971246
#                                                 f_evals          18
#                                          DIM10  f        115.381262
#                                                 f_evals         255
#                                          DIM20  f        494.247775
#                                                 f_evals          20
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_naiveBayes                            DIM2   f         16.790164
#                                                 f_evals           2
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
#                                          DIM10  f               NaN
#                                                 f_evals         NaN
#                                          DIM20  f               NaN
#                                                 f_evals         NaN
#                                          DIM40  f               NaN
#                                                 f_evals         NaN
# BO_naiveBayes-001                        DIM2   f          4.007262
#                                                 f_evals          18
#                                          DIM3   f               NaN
#                                                 f_evals         NaN
#                                          DIM5   f               NaN
#                                                 f_evals         NaN
# ...
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM3   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM5   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#
#                                                                  f20  \
# first                                    second third
# BO_GP                                    DIM2   f           2.227583
#                                                 f_evals           14
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression     DIM2   f           1.227896
#                                                 f_evals           56
#                                          DIM3   f           2.445465
#                                                 f_evals            6
#                                          DIM5   f         372.732314
#                                                 f_evals          138
#                                          DIM10  f         6184.23738
#                                                 f_evals          132
#                                          DIM20  f        17695.12418
#                                                 f_evals          241
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes                            DIM2   f           2.158771
#                                                 f_evals           50
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_naiveBayes-001                        DIM2   f           1.227896
#                                                 f_evals           56
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f                NaN
#                                                 f_evals          NaN
#                                          DIM3   f                NaN
#                                                 f_evals          NaN
#                                          DIM5   f                NaN
#                                                 f_evals          NaN
#                                          DIM10  f                NaN
#                                                 f_evals          NaN
#                                          DIM20  f                NaN
#                                                 f_evals          NaN
#                                          DIM40  f                NaN
#                                                 f_evals          NaN
#
#                                                                f21        f22  \
# first                                    second third
# BO_GP                                    DIM2   f         2.284567   0.228528
#                                                 f_evals         14         17
#                                          DIM3   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM5   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
# BO_empirical_mean_and_std_regression     DIM2   f         0.003761   0.000239
#                                                 f_evals         50         55
#                                          DIM3   f         0.026916    2.20577
#                                                 f_evals         43          7
#                                          DIM5   f         8.628166   40.18462
#                                                 f_evals         48        110
#                                          DIM10  f        57.053956  61.692022
#                                                 f_evals        282        235
#                                          DIM20  f        70.608296  81.165803
#                                                 f_evals        304        170
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
# BO_naiveBayes                            DIM2   f         2.082161   0.774594
#                                                 f_evals         19          2
#                                          DIM3   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM5   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
# BO_naiveBayes-001                        DIM2   f         0.003761   0.000239
#                                                 f_evals         50         55
#                                          DIM3   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM5   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM3   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM5   f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM10  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM20  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#                                          DIM40  f              NaN        NaN
#                                                 f_evals        NaN        NaN
#
#                                                               f23         f24
# first                                    second third
# BO_GP                                    DIM2   f         8.85392   11.790575
#                                                 f_evals         7           4
#                                          DIM3   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM5   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM10  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM20  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM40  f             NaN         NaN
#                                                 f_evals       NaN         NaN
# BO_empirical_mean_and_std_regression     DIM2   f         2.84529    3.820618
#                                                 f_evals         5          22
#                                          DIM3   f        2.427541    20.09956
#                                                 f_evals        88           1
#                                          DIM5   f        2.787224   69.641134
#                                                 f_evals        37         127
#                                          DIM10  f        4.265199  167.079433
#                                                 f_evals       267          84
#                                          DIM20  f        3.356044  475.219801
#                                                 f_evals       258         578
#                                          DIM40  f             NaN         NaN
#                                                 f_evals       NaN         NaN
# BO_naiveBayes                            DIM2   f        6.361085    6.667134
#                                                 f_evals        27          34
#                                          DIM3   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM5   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM10  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM20  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM40  f             NaN         NaN
#                                                 f_evals       NaN         NaN
# BO_naiveBayes-001                        DIM2   f         2.84529    3.820618
#                                                 f_evals         5          22
#                                          DIM3   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM5   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM10  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM20  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM40  f             NaN         NaN
#                                                 f_evals       NaN         NaN
# BO_empirical_mean_and_std_regression-001 DIM2   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM3   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM5   f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM10  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM20  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#                                          DIM40  f             NaN         NaN
#                                                 f_evals       NaN         NaN
#
# [60 rows x 24 columns]
