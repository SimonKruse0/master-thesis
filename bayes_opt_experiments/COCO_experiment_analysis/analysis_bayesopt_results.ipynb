# %%
from collect_bayesopt_results import get_best_solutions_for_all_solvers

# %%
df = get_best_solutions_for_all_solvers()
df
# Out:
#                                                            f1          f2  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f             NaN         NaN
#                                             f_evals       NaN         NaN
#                                      DIM2   f        0.074467  552.830941
#                                             f_evals        39          27
#                                      DIM20  f             NaN         NaN
# ...                                                       ...         ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals       NaN         NaN
#                                      DIM40  f             NaN         NaN
#                                             f_evals       NaN         NaN
#                                      DIM5   f             NaN         NaN
#                                             f_evals       NaN         NaN
#
#                                                            f3         f4  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM2   f        5.505196  10.334109
#                                             f_evals        33         37
#                                      DIM20  f             NaN        NaN
# ...                                                       ...        ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals       NaN        NaN
#                                      DIM40  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM5   f             NaN        NaN
#                                             f_evals       NaN        NaN
#
#                                                            f5        f6  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM2   f        0.026431  0.045508
#                                             f_evals        28        33
#                                      DIM20  f             NaN       NaN
# ...                                                       ...       ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals       NaN       NaN
#                                      DIM40  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM5   f             NaN       NaN
#                                             f_evals       NaN       NaN
#
#                                                            f7   f8   f9  f10  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM2   f        1.683498  NaN  NaN  NaN
#                                             f_evals        17  NaN  NaN  NaN
#                                      DIM20  f             NaN  NaN  NaN  NaN
# ...                                                       ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals       NaN  NaN  NaN  NaN
#                                      DIM40  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM5   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#
#                                                      ...  f15  f16  f17  f18  \
# first                                second third    ...
# BO_BOHAMIANN                         DIM10  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM2   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM20  f        ...  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM40  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM5   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#
#                                                      f19  f20  f21  f22  f23  \
# first                                second third
# BO_BOHAMIANN                         DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#
#                                                      f24
# first                                second third
# BO_BOHAMIANN                         DIM10  f        NaN
#                                             f_evals  NaN
#                                      DIM2   f        NaN
#                                             f_evals  NaN
#                                      DIM20  f        NaN
# ...                                                  ...
# BO_numpyro_neural_network200-200-002 DIM3   f_evals  NaN
#                                      DIM40  f        NaN
#                                             f_evals  NaN
#                                      DIM5   f        NaN
#                                             f_evals  NaN
#
# [156 rows x 24 columns]

# %%
mask = ["BO_num" in x for x in df.index.get_level_values(0).values]
df[mask]
# Out:
#                                                             f1          f2  \
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM2   f        12.461881         NaN
#                                             f_evals          1         NaN
#                                      DIM20  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM3   f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM40  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM5   f              NaN         NaN
#                                             f_evals        NaN         NaN
# BO_numpyro_neural_network200-200-001 DIM10  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM2   f          0.69918  897.134213
#                                             f_evals         19          39
#                                      DIM20  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM3   f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM40  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM5   f              NaN         NaN
#                                             f_evals        NaN         NaN
# BO_numpyro_neural_network200-200-002 DIM10  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM2   f          0.69918  897.134213
#                                             f_evals         19          39
#                                      DIM20  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM3   f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM40  f              NaN         NaN
#                                             f_evals        NaN         NaN
#                                      DIM5   f              NaN         NaN
#                                             f_evals        NaN         NaN
#
#                                                            f3         f4  \
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM2   f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM20  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM3   f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM40  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM5   f             NaN        NaN
#                                             f_evals       NaN        NaN
# BO_numpyro_neural_network200-200-001 DIM10  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM2   f        2.067178  10.142114
#                                             f_evals        36         39
#                                      DIM20  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM3   f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM40  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM5   f             NaN        NaN
#                                             f_evals       NaN        NaN
# BO_numpyro_neural_network200-200-002 DIM10  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM2   f        2.067178  10.142114
#                                             f_evals        36         39
#                                      DIM20  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM3   f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM40  f             NaN        NaN
#                                             f_evals       NaN        NaN
#                                      DIM5   f             NaN        NaN
#                                             f_evals       NaN        NaN
#
#                                                            f5        f6  \
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM2   f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM20  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM3   f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM40  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM5   f             NaN       NaN
#                                             f_evals       NaN       NaN
# BO_numpyro_neural_network200-200-001 DIM10  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM2   f        0.026431  1.309995
#                                             f_evals        28        28
#                                      DIM20  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM3   f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM40  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM5   f             NaN       NaN
#                                             f_evals       NaN       NaN
# BO_numpyro_neural_network200-200-002 DIM10  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM2   f        0.026431  1.309995
#                                             f_evals        28        28
#                                      DIM20  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM3   f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM40  f             NaN       NaN
#                                             f_evals       NaN       NaN
#                                      DIM5   f             NaN       NaN
#                                             f_evals       NaN       NaN
#
#                                                            f7   f8   f9  f10  \
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM2   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM20  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM3   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM40  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM5   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001 DIM10  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM2   f        3.229661  NaN  NaN  NaN
#                                             f_evals         4  NaN  NaN  NaN
#                                      DIM20  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM3   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM40  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM5   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-002 DIM10  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM2   f        2.068634  NaN  NaN  NaN
#                                             f_evals        17  NaN  NaN  NaN
#                                      DIM20  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM3   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM40  f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#                                      DIM5   f             NaN  NaN  NaN  NaN
#                                             f_evals       NaN  NaN  NaN  NaN
#
#                                                      ...  f15  f16  f17  f18  \
# first                                second third    ...
# BO_numpyro_neural_network200-200     DIM10  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM2   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM20  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM3   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM40  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM5   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001 DIM10  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM2   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM20  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM3   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM40  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM5   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-002 DIM10  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM2   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM20  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM3   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM40  f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#                                      DIM5   f        ...  NaN  NaN  NaN  NaN
#                                             f_evals  ...  NaN  NaN  NaN  NaN
#
#                                                      f19  f20  f21  f22  f23  \
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM3   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-001 DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM3   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
# BO_numpyro_neural_network200-200-002 DIM10  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM2   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM20  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM3   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM40  f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#                                      DIM5   f        NaN  NaN  NaN  NaN  NaN
#                                             f_evals  NaN  NaN  NaN  NaN  NaN
#
#                                                      f24
# first                                second third
# BO_numpyro_neural_network200-200     DIM10  f        NaN
#                                             f_evals  NaN
#                                      DIM2   f        NaN
#                                             f_evals  NaN
#                                      DIM20  f        NaN
#                                             f_evals  NaN
#                                      DIM3   f        NaN
#                                             f_evals  NaN
#                                      DIM40  f        NaN
#                                             f_evals  NaN
#                                      DIM5   f        NaN
#                                             f_evals  NaN
# BO_numpyro_neural_network200-200-001 DIM10  f        NaN
#                                             f_evals  NaN
#                                      DIM2   f        NaN
#                                             f_evals  NaN
#                                      DIM20  f        NaN
#                                             f_evals  NaN
#                                      DIM3   f        NaN
#                                             f_evals  NaN
#                                      DIM40  f        NaN
#                                             f_evals  NaN
#                                      DIM5   f        NaN
#                                             f_evals  NaN
# BO_numpyro_neural_network200-200-002 DIM10  f        NaN
#                                             f_evals  NaN
#                                      DIM2   f        NaN
#                                             f_evals  NaN
#                                      DIM20  f        NaN
#                                             f_evals  NaN
#                                      DIM3   f        NaN
#                                             f_evals  NaN
#                                      DIM40  f        NaN
#                                             f_evals  NaN
#                                      DIM5   f        NaN
#                                             f_evals  NaN
#
# [36 rows x 24 columns]

# %%
mean_opt = df[mask].loc[:,"DIM5","f"].mean()[:3]
mean_opt
# Out:
# f1        5.863391
# f2    11159.862790
# f3       59.177109
# dtype: float64

# %%
import latextable
from texttable import Texttable
from tabulate import tabulate

# %%
table_1 = Texttable()
table_1.set_cols_align(["l", "r", "c"])
table_1.set_cols_valign(["t", "m", "b"])
#table.set_cols_align(["c"] * 4)
rows = [["f1", "f2", "f3"],
                [f"{x:0.2f}" for x in mean_opt],
                [f"{x:0.1f}" for x in mean_opt],
                [f"{x:0.0f}" for x in mean_opt]]
table_1.set_deco(Texttable.HEADER | Texttable.VLINES)
table_1.add_rows(rows)

texdoc = tabulate(rows, headers='firstrow', tablefmt='latex')
#texdoc = latextable.draw_latex(table_1, caption="An example table.", label="table:example_table")
path = "/home/simon/Documents/MasterThesis/master-thesis/thesis/Tables"
with open(f'{path}/test.tex', 'w') as fout:
    for i in range(len(texdoc)):
        fout.write(texdoc[i])
